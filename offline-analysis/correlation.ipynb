# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline

data = pd.read_csv("./data/enhanced_block.csv", names=["BLOCK", "SIZE", "VERSION", "numberTX", "numberVin", "numberVout", "numberJoinSplit", "numbervShieldedSpend", "numbervShieldedOutput"])

# %%
corrMatrix = data.corr()
sn.heatmap(corrMatrix, annot=True)
plt.show()

# %%
print(abs(corrMatrix['']))
